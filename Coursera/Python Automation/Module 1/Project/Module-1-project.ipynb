# %%
# %pip install wordcloud
# %pip install fileupload
# %pip install ipywidgets
# %pip install jupyterlab
# !jupyter nbextension install --py --user fileupload
# !jupyter nbextension enable --py fileupload
# !jupyter nbextension enable --py widgetsnbextension
# !jupyter labextension install "@jupyter-widgets/jupyterlab-manager"

import wordcloud
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display
import fileupload
from ipywidgets import FileUpload
import io
import sys
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp310-cp310-win_amd64.whl (153 kB)
#      ------------------------------------ 153.1/153.1 KB 480.8 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: matplotlib in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (9.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.33.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\shihu\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: fileupload in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (0.1.5)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: ipywidgets>=5.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from fileupload) (7.7.0)
# Requirement already satisfied: notebook>=4.2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from fileupload) (6.4.11)
# Requirement already satisfied: traitlets>=4.2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from fileupload) (5.2.1.post0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=5.1->fileupload) (5.4.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=5.1->fileupload) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=5.1->fileupload) (8.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=5.1->fileupload) (6.13.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=5.1->fileupload) (1.1.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=5.1->fileupload) (3.6.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.2->fileupload) (0.15.0)
# Requirement already satisfied: argon2-cffi in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.2->fileupload) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.2->fileupload) (4.10.0)
# Requirement already satisfied: jinja2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.2->fileupload) (3.1.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.2->fileupload) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.2->fileupload) (0.14.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.2->fileupload) (7.3.1)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.2->fileupload) (1.5.5)
# Requirement already satisfied: tornado>=6.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.2->fileupload) (6.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.2->fileupload) (23.0.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.2->fileupload) (6.5.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (1.6.0)
# Requirement already satisfied: psutil in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (0.1.3)
# Requirement already satisfied: packaging in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (21.3)
# Requirement already satisfied: backcall in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.2.0)
# Requirement already satisfied: colorama in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.4.4)
# Requirement already satisfied: stack-data in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (58.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (3.0.29)
# Requirement already satisfied: pickleshare in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.7.5)
# Requirement already satisfied: decorator in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (2.12.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.18.1)
# Requirement already satisfied: entrypoints in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.2->fileupload) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.2->fileupload) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.2->fileupload) (304)
# Requirement already satisfied: jupyterlab-pygments in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.8.4)
# Requirement already satisfied: tinycss2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.6.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (4.11.1)
# Requirement already satisfied: defusedxml in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.7.1)
# Requirement already satisfied: bleach in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (2.1.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=5.1->fileupload) (4.5.1)
# Requirement already satisfied: fastjsonschema in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=5.1->fileupload) (2.15.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from terminado>=0.8.3->notebook>=4.2->fileupload) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi->notebook>=4.2->fileupload) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=5.1->fileupload) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=5.1->fileupload) (0.18.1)
# Requirement already satisfied: wcwidth in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->notebook>=4.2->fileupload) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.2->fileupload) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.2->fileupload) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.2->fileupload) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (3.0.9)
# Requirement already satisfied: executing in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=5.1->fileupload) (2.0.5)
# Requirement already satisfied: pycparser in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.2->fileupload) (2.21)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\shihu\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: ipywidgets in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (7.7.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (3.6.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (1.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (6.13.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (5.2.1.post0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (5.4.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (8.3.0)
# Requirement already satisfied: psutil in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.3.1)
# Requirement already satisfied: nest-asyncio in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: packaging in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: setuptools>=18.5 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (58.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: colorama in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.12.0)
# Requirement already satisfied: decorator in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: backcall in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.29)
# Requirement already satisfied: fastjsonschema in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (2.15.3)
# Requirement already satisfied: jupyter-core in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.5.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.4.11)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (23.0.0)
# Requirement already satisfied: entrypoints in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets) (304)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.15.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.14.1)
# Requirement already satisfied: argon2-cffi in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.2)
# Requirement already satisfied: wcwidth in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: executing in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: bleach in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.0.0)
# Requirement already satisfied: defusedxml in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.11.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\shihu\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Collecting jupyterlab
#   Downloading jupyterlab-3.4.3-py3-none-any.whl (8.8 MB)
#      ---------------------------------------- 8.8/8.8 MB 2.5 MB/s eta 0:00:00
# Collecting jupyterlab-server~=2.10
#   Downloading jupyterlab_server-2.15.0-py3-none-any.whl (54 kB)
#      -------------------------------------- 54.1/54.1 KB 402.3 kB/s eta 0:00:00
# Requirement already satisfied: jupyter-core in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (4.10.0)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (6.1)
# Requirement already satisfied: jinja2>=2.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (3.1.2)
# Collecting jupyter-server~=1.16
#   Downloading jupyter_server-1.18.1-py3-none-any.whl (344 kB)
#      -------------------------------------- 344.9/344.9 KB 1.6 MB/s eta 0:00:00
# Collecting nbclassic~=0.2
#   Downloading nbclassic-0.4.3-py3-none-any.whl (9.7 MB)
#      ---------------------------------------- 9.7/9.7 MB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (21.3)
# Requirement already satisfied: ipython in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (8.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jinja2>=2.1->jupyterlab) (2.1.1)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      ---------------------------------------- 80.6/80.6 KB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (6.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (21.3.0)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (5.4.0)
# Requirement already satisfied: prometheus-client in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (0.15.0)
# Collecting websocket-client
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
#      -------------------------------------- 54.3/54.3 KB 936.5 kB/s eta 0:00:00
# Requirement already satisfied: pywinpty in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (2.0.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (7.3.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (5.2.1.post0)
# Requirement already satisfied: Send2Trash in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (23.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core->jupyterlab) (304)
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 KB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (4.5.1)
# Collecting json5
#   Downloading json5-0.9.8.tar.gz (22 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting babel
#   Downloading Babel-2.10.3-py3-none-any.whl (9.5 MB)
#      ---------------------------------------- 9.5/9.5 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbclassic~=0.2->jupyterlab) (6.13.0)
# Collecting notebook-shim>=0.1.0
#   Downloading notebook_shim-0.1.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: ipython-genutils in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbclassic~=0.2->jupyterlab) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbclassic~=0.2->jupyterlab) (1.5.5)
# Requirement already satisfied: matplotlib-inline in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython->jupyterlab) (0.1.3)
# Requirement already satisfied: stack-data in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: colorama in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython->jupyterlab) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython->jupyterlab) (0.7.5)
# Requirement already satisfied: backcall in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython->jupyterlab) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython->jupyterlab) (3.0.29)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython->jupyterlab) (2.12.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython->jupyterlab) (58.1.0)
# Requirement already satisfied: decorator in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipython->jupyterlab) (5.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from packaging->jupyterlab) (3.0.9)
# Collecting idna>=2.8
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.2/61.2 KB 1.1 MB/s eta 0:00:00
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython->jupyterlab) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab) (21.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab) (0.4)
# Requirement already satisfied: defusedxml in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.7.1)
# Requirement already satisfied: bleach in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (5.0.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.6.3)
# Requirement already satisfied: tinycss2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.8.4)
# Requirement already satisfied: fastjsonschema in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=5.2.0->jupyter-server~=1.16->jupyterlab) (2.15.3)
# Requirement already satisfied: wcwidth in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi->jupyter-server~=1.16->jupyterlab) (21.2.0)
# Collecting pytz>=2015.7
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      -------------------------------------- 503.5/503.5 KB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: debugpy>=1.0 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->nbclassic~=0.2->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->nbclassic~=0.2->jupyterlab) (5.9.1)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.6.15-py3-none-any.whl (160 kB)
#      -------------------------------------- 160.2/160.2 KB 1.6 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.10-py2.py3-none-any.whl (139 kB)
#      ------------------------------------ 139.2/139.2 KB 821.3 kB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: pure-eval in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->jupyterlab) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->jupyterlab) (2.0.5)
# Requirement already satisfied: executing in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->jupyterlab) (0.8.3)
# Requirement already satisfied: six>=1.5 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\shihu\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab) (2.21)
# Using legacy 'setup.py install' for json5, since package 'wheel' is not installed.
# Installing collected packages: pytz, json5, websocket-client, urllib3, sniffio, idna, charset-normalizer, certifi, babel, requests, anyio, jupyter-server, notebook-shim, jupyterlab-server, nbclassic, jupyterlab
#   Running setup.py install for json5: started
#   Running setup.py install for json5: finished with status 'done'
# Successfully installed anyio-3.6.1 babel-2.10.3 certifi-2022.6.15 charset-normalizer-2.1.0 idna-3.3 json5-0.9.8 jupyter-server-1.18.1 jupyterlab-3.4.3 jupyterlab-server-2.15.0 nbclassic-0.4.3 notebook-shim-0.1.0 pytz-2022.1 requests-2.28.1 sniffio-1.2.0 urllib3-1.26.10 websocket-client-1.3.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\shihu\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Installing c:\Users\shihu\AppData\Local\Programs\Python\Python310\lib\site-packages\fileupload\static -> fileupload
# Out of date: C:\Users\shihu\AppData\Roaming\jupyter\nbextensions\fileupload\extension.js
# Copying: c:\Users\shihu\AppData\Local\Programs\Python\Python310\lib\site-packages\fileupload\static\extension.js -> C:\Users\shihu\AppData\Roaming\jupyter\nbextensions\fileupload\extension.js
# Out of date: C:\Users\shihu\AppData\Roaming\jupyter\nbextensions\fileupload\widget.js
# Copying: c:\Users\shihu\AppData\Local\Programs\Python\Python310\lib\site-packages\fileupload\static\widget.js -> C:\Users\shihu\AppData\Roaming\jupyter\nbextensions\fileupload\widget.js
# Out of date: C:\Users\shihu\AppData\Roaming\jupyter\nbextensions\fileupload\fileupload\widget.js
# Copying: c:\Users\shihu\AppData\Local\Programs\Python\Python310\lib\site-packages\fileupload\static\fileupload\widget.js -> C:\Users\shihu\AppData\Roaming\jupyter\nbextensions\fileupload\fileupload\widget.js
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable fileupload --user --py
#
# Enabling notebook extension fileupload/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# Building jupyterlab assets (production, minimized)

# %%
def _upload():

    _upload_widget = fileupload.FileUploadWidget()

    def _cb(change):
        global file_contents
        decoded = io.StringIO(change['owner'].data.decode('utf-8'))
        filename = change['owner'].filename
        print('Uploaded `{}` ({:.2f} kB)'.format(
            filename, len(decoded.read()) / 2 **10))
        file_contents = decoded.getvalue()

    _upload_widget.observe(_cb, names='data')
    display(_upload_widget)

_upload()
# Out:
# FileUploadWidget(label='Browse', _dom_classes=('widget_item', 'btn-group'))

# %%
def calculate_frequencies(file_contents):
    # Here is a list of punctuations and uninteresting words you can use to process your text
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    uninteresting_words = ["the", "a", "to", "if", "is", "it", "of", "and", "or", "an", "as", "i", "me", "my", \
    "we", "our", "ours", "you", "your", "yours", "he", "she", "him", "his", "her", "hers", "its", "they", "them", \
    "their", "what", "which", "who", "whom", "this", "that", "am", "are", "was", "were", "be", "been", "being", \
    "have", "has", "had", "do", "does", "did", "but", "at", "by", "with", "from", "here", "when", "where", "how", \
    "all", "any", "both", "each", "few", "more", "some", "such", "no", "nor", "too", "very", "can", "will", "just"]
    
    # LEARNER CODE START HERE
    word_dict = {}
    word_list = file_contents.split()
    output_list = []
    
    for word in word_list:
        word_str = ""
        for letter in word.lower():
            if letter.isalpha() and letter not in punctuations:
                word_str += letter
            
        if word not in uninteresting_words:
            output_list.append(word_str)
            
    for word in output_list:
        if word not in word_dict:
            word_dict[word] = 0
        word_dict[word] += 1
    
    #wordcloud
    cloud = wordcloud.WordCloud()
    cloud.generate_from_frequencies()
    return cloud.to_array()

# %%
# Display your wordcloud image

myimage = calculate_frequencies(file_contents)
plt.imshow(myimage, interpolation = 'nearest')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Learn Python\Coursera\Python Automation\Module 1\Project\Module-1-project.ipynb Cell 4' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/Learn%20Python/Coursera/Python%20Automation/Module%201/Project/Module-1-project.ipynb#ch0000003?line=0'>1</a> # Display your wordcloud image
# ----> <a href='vscode-notebook-cell:/d%3A/Learn%20Python/Coursera/Python%20Automation/Module%201/Project/Module-1-project.ipynb#ch0000003?line=2'>3</a> myimage = calculate_frequencies(file_contents)
#       <a href='vscode-notebook-cell:/d%3A/Learn%20Python/Coursera/Python%20Automation/Module%201/Project/Module-1-project.ipynb#ch0000003?line=3'>4</a> plt.imshow(myimage, interpolation = 'nearest')
#       <a href='vscode-notebook-cell:/d%3A/Learn%20Python/Coursera/Python%20Automation/Module%201/Project/Module-1-project.ipynb#ch0000003?line=4'>5</a> plt.axis('off')
#
# NameError: name 'file_contents' is not defined
